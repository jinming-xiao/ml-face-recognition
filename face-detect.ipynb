# %%
from IPython.display import display, Image

import face_recognition

picture_of_me = face_recognition.load_image_file("0227.jpeg")
my_face_encoding = face_recognition.face_encodings(picture_of_me)[0]

# my_face_encoding now contains a universal 'encoding' of my facial features 
# that can be compared to any other picture of a face!

unknown_picture = face_recognition.load_image_file("0010.jpg")
unknown_face_encoding = face_recognition.face_encodings(unknown_picture)[0]

# Now we can see the two face encodings are of the same person with `compare_faces`!

results = face_recognition.compare_faces([my_face_encoding], unknown_face_encoding)

if results[0] == True:
    print("It's a picture of me!")
else:
    print("It's not a picture of me!")
# Out:
# It's not a picture of me!

# %%
# execution steps
display(Image(filename='try-00.jpg'))

# %%
import face_recognition

# %%
# detail function call for import
display(Image(filename='try-01.jpg'))

# %%
picture_of_me = face_recognition.load_image_file("0227.jpeg")

# %%
# detail of load_image_file()
display(Image(filename='try-02.jpg'))

# %%
my_face_encoding = face_recognition.face_encodings(picture_of_me)[0]

# %%
# detail of face_encodings()
display(Image(filename='try-03.jpg'))

# %%
unknown_picture = face_recognition.load_image_file("0010.jpg")

# %%
# detail of load_image_file()
display(Image(filename='try-04.jpg'))

# %%
unknown_face_encoding = face_recognition.face_encodings(unknown_picture)[0]

# %%
# detail of face_encodings()
display(Image(filename='try-05.jpg'))

# %%
results = face_recognition.compare_faces([my_face_encoding], unknown_face_encoding)

# %%
# detail of compare_faces()
display(Image(filename='try-06.jpg'))
